# %%
import pandas as pd
import numpy as np

# %%
data_match = pd.read_excel('FIFA World Cup 2018.xlsx', sheet_name= 'match_statistics')
data_cou = pd.read_excel('FIFA World Cup 2018.xlsx', sheet_name= 'countries')
data_match.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow Card  \
# 0        13          7           3        3        6  ...            0
# 1         6          0           3        3        2  ...            0
# 2         8          3           3        2        0  ...            2
# 3        14          4           6        4        5  ...            0
# 4        13          3           6        4        5  ...            1
#
#    Yellow & Red  Red  Man of the Match  1st Goal        Round  PSO  \
# ...

# %%
data_cou.head()
# Out:
#      Country      Continent
# 0  Argentina  South America
# 1  Australia           Asia
# 2    Belgium         Europe
# 3     Brazil  South America
# 4   Colombia  South America

# %%
data_match.head(8)
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
# 5  15-06-2018          Iran       Morocco            1                 36
# 6  15-06-2018      Portugal         Spain            3                 39
# 7  15-06-2018         Spain      Portugal            3                 61
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  ...  Yellow Card  \
# 0        13          7           3        3        6  ...            0
# 1         6          0           3        3        2  ...            0
# 2         8          3           3        2        0  ...            2
# ...

# %%
data_cou.tail(3)
# Out:
#         Country      Continent
# 29  Switzerland         Europe
# 30      Tunisia         Africa
# 31      Uruguay  South America

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 27 columns):
# Date                      128 non-null object
# Team                      128 non-null object
# Opponent                  128 non-null object
# Goal Scored               128 non-null int64
# Ball Possession %         128 non-null int64
# Attempts                  128 non-null int64
# On-Target                 128 non-null int64
# Off-Target                128 non-null int64
# Blocked                   128 non-null int64
# Corners                   128 non-null int64
# Offsides                  128 non-null int64
# Free Kicks                128 non-null int64
# Saves                     128 non-null int64
# Pass Accuracy %           128 non-null int64
# Passes                    128 non-null int64
# Distance Covered (Kms)    128 non-null int64
# Fouls Committed           128 non-null int64
# Yellow Card               128 non-null int64
# ...

# %%
data_match.describe()
# Out:
#        Goal Scored  Ball Possession %    Attempts   On-Target  Off-Target  \
# count   128.000000         128.000000  128.000000  128.000000  128.000000
# mean      1.320312          49.992188   12.593750    3.914062    5.273438
# std       1.156519          10.444074    5.245827    2.234403    2.409675
# min       0.000000          25.000000    3.000000    0.000000    1.000000
# 25%       0.000000          42.000000    9.000000    2.000000    4.000000
# 50%       1.000000          50.000000   12.000000    3.500000    5.000000
# 75%       2.000000          58.000000   15.000000    5.000000    7.000000
# max       6.000000          75.000000   26.000000   12.000000   11.000000
#
#           Blocked     Corners    Offsides  Free Kicks       Saves  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000
# mean     3.359375    4.718750    1.343750   14.890625    2.726562
# std      2.403195    2.446072    1.193404    4.724262    2.049447
# ...

# %%
data_match = data_match.sort_values(by = ['Team','Date']).reset_index()
data_match
# Out:
#      index                 Date            Team        Opponent  Goal Scored  \
# 0       10           16-06-2018       Argentina         Iceland            1
# 1       44           21-06-2018       Argentina         Croatia            0
# 2       77           26-06-2018       Argentina         Nigeria            2
# 3       97           30-06-2018       Argentina          France            3
# 4        9           16-06-2018       Australia          France            1
# 5       41           21-06-2018       Australia         Denmark            1
# 6       74           26-06-2018       Australia            Peru            0
# 7      106  2018-02-07 00:00:00         Belgium           Japan            3
# 8      115  2018-06-07 00:00:00         Belgium          Brazil            2
# 9      121  2018-10-07 00:00:00         Belgium          France            0
# 10     124           14-07-2018         Belgium         England            2
# ...

# %%
data_match= data_match[data_match['Round'] == 'Group Stage']
data_match
# Out:
#      index        Date            Team        Opponent  Goal Scored  \
# 0       10  16-06-2018       Argentina         Iceland            1
# 1       44  21-06-2018       Argentina         Croatia            0
# 2       77  26-06-2018       Argentina         Nigeria            2
# 4        9  16-06-2018       Australia          France            1
# 5       41  21-06-2018       Australia         Denmark            1
# 6       74  26-06-2018       Australia            Peru            0
# 11      24  18-06-2018         Belgium          Panama            3
# 12      52  23-06-2018         Belgium         Tunisia            5
# 13      95  28-06-2018         Belgium         England            1
# 16      20  17-06-2018          Brazil     Switzerland            1
# 17      46  22-06-2018          Brazil      Costa Rica            2
# 18      85  27-06-2018          Brazil          Serbia            2
# 20      28  19-06-2018        Colombia           Japan            1
# ...

# %%
data_match[data_match['Goal Scored'] > 3]
# Out:
#     index        Date     Team      Opponent  Goal Scored  Ball Possession %  \
# 12     52  23-06-2018  Belgium       Tunisia            5                 52
# 45     58  24-06-2018  England        Panama            6                 58
# 95      0  14-06-2018   Russia  Saudi Arabia            5                 40
#
#     Attempts  On-Target  Off-Target  Blocked  Corners  Offsides  Free Kicks  \
# 12        23         12           8        3        5         3          16
# 45        12          7           3        2        3         3          13
# 95        13          7           3        3        6         3          11
#
#     Saves  Pass Accuracy %  Passes  Distance Covered (Kms)  Fouls Committed  \
# 12      3               84     468                     104               12
# 45      1               94     593                      99               14
# 95      0               78     306                     118               22
#
# ...

# %%
data_match['Passes Completed'] = data_match['Passes'] * (data_match['Pass Accuracy %'] / 100)
data_match.head()
# Out:
# /Users/fahmi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    index        Date       Team Opponent  Goal Scored  Ball Possession %  \
# 0     10  16-06-2018  Argentina  Iceland            1                 72
# 1     44  21-06-2018  Argentina  Croatia            0                 58
# 2     77  26-06-2018  Argentina  Nigeria            2                 66
# 4      9  16-06-2018  Australia   France            1                 49
# 5     41  21-06-2018  Australia  Denmark            1                 51
#
#    Attempts  On-Target  Off-Target  Blocked  Corners  Offsides  Free Kicks  \
# ...

# %%
data_match.groupby(['Goal Scored']).mean()
# Out:
#                  index  Ball Possession %   Attempts  On-Target  Off-Target  \
# Goal Scored
# 0            47.185185          50.148148  10.962963   2.592593    5.074074
# 1            42.588235          46.794118  11.382353   3.352941    5.000000
# 2            58.500000          54.541667  13.333333   4.791667    5.458333
# 3            40.500000          49.500000  13.000000   4.625000    5.375000
# 5            26.000000          46.000000  18.000000   9.500000    5.500000
# 6            58.000000          58.000000  12.000000   7.000000    3.000000
#
#               Blocked   Corners  Offsides  Free Kicks     Saves  \
# Goal Scored
# 0            3.296296  4.444444  1.666667   15.259259  2.481481
# 1            3.029412  3.941176  1.117647   14.588235  3.029412
# 2            3.083333  5.375000  1.791667   15.125000  2.666667
# 3            3.000000  4.875000  1.125000   15.875000  1.625000
# 5            3.000000  5.500000  3.000000   13.500000  1.500000
# ...

# %%
data_match.groupby(['Team','Goal Scored']).mean()
# Out:
#                             index  Ball Possession %  Attempts  On-Target  \
# Team           Goal Scored
# Argentina      0             44.0               58.0      10.0        3.0
#                1             10.0               72.0      26.0        7.0
#                2             77.0               66.0       8.0        4.0
# Australia      0             74.0               53.0      14.0        2.0
#                1             25.0               50.0       9.0        3.0
# Belgium        1             95.0               52.0      15.0        4.0
#                3             24.0               61.0      15.0        6.0
#                5             52.0               52.0      23.0       12.0
# Brazil         1             20.0               52.0      20.0        4.0
#                2             65.5               61.0      18.0        7.5
# Colombia       1             59.5               49.0       6.0        2.5
# ...

# %%
data_match[(data_match['Goal Scored'] >= 2) & (data_match['Passes Completed'] > 500)]
# Out:
#      index        Date          Team    Opponent  Goal Scored  \
# 17      46  22-06-2018        Brazil  Costa Rica            2
# 18      85  27-06-2018        Brazil      Serbia            2
# 45      58  24-06-2018       England      Panama            6
# 55      56  23-06-2018       Germany      Sweden            2
# 100     66  25-06-2018  Saudi Arabia       Egypt            2
# 108      7  15-06-2018         Spain    Portugal            3
# 110     68  25-06-2018         Spain     Morocco            2
# 119     86  27-06-2018   Switzerland  Costa Rica            2
# 122     93  28-06-2018       Tunisia      Panama            2
#
#      Ball Possession %  Attempts  On-Target  Off-Target  Blocked  Corners  \
# 17                  66        23          9           9        5       10
# 18                  56        13          6           3        4        9
# 45                  58        12          7           3        2        3
# ...

# %%
data_match = data_match.sort_values(by='Goal Scored', ascending=False).reset_index()
data_match
# Out:
#     level_0  index        Date            Team        Opponent  Goal Scored  \
# 0        45     58  24-06-2018         England          Panama            6
# 1        95      0  14-06-2018          Russia    Saudi Arabia            5
# 2        12     52  23-06-2018         Belgium         Tunisia            5
# 3       126     64  25-06-2018         Uruguay          Russia            3
# 4        21     63  24-06-2018        Colombia          Poland            3
# 5        89      6  15-06-2018        Portugal           Spain            3
# 6        96     32  19-06-2018          Russia           Egypt            3
# 7        31     45  21-06-2018         Croatia       Argentina            3
# 8       115     83  27-06-2018          Sweden          Mexico            3
# 9       108      7  15-06-2018           Spain        Portugal            3
# 10       11     24  18-06-2018         Belgium          Panama            3
# ...

# %%
def get_stats(group):
    return {'min': group.min(), 'max': group.max(), 'mean': group.mean()}

# %%
data_match['Goal Scored'].groupby(data_match['Team']).apply(get_stats).unstack()
# Out:
#                 max      mean  min
# Team
# Argentina       2.0  1.000000  0.0
# Australia       1.0  0.666667  0.0
# Belgium         5.0  3.000000  1.0
# Brazil          2.0  1.666667  1.0
# Colombia        3.0  1.666667  1.0
# Costa Rica      2.0  0.666667  0.0
# Croatia         3.0  2.333333  2.0
# Denmark         1.0  0.666667  0.0
# Egypt           1.0  0.666667  0.0
# England         6.0  2.666667  0.0
# France          2.0  1.000000  0.0
# Germany         2.0  0.666667  0.0
# Iceland         1.0  0.666667  0.0
# Iran            1.0  0.666667  0.0
# Japan           2.0  1.333333  0.0
# Korea Republic  2.0  1.000000  0.0
# Mexico          2.0  1.000000  0.0
# Morocco         2.0  0.666667  0.0
# Nigeria         2.0  1.000000  0.0
# Panama          1.0  0.666667  0.0
# Peru            2.0  0.666667  0.0
# Poland          1.0  0.666667  0.0
# Portugal        3.0  1.666667  1.0
# Russia          5.0  2.666667  0.0
# Saudi Arabia    2.0  0.666667  0.0
# ...

# %%
new_filter = data_match[['Date','Team','Opponent','Goal Scored','Attempts','On-Target','Passes Completed']]
new_filter
# Out:
#           Date            Team        Opponent  Goal Scored  Attempts  \
# 0   24-06-2018         England          Panama            6        12
# 1   14-06-2018          Russia    Saudi Arabia            5        13
# 2   23-06-2018         Belgium         Tunisia            5        23
# 3   25-06-2018         Uruguay          Russia            3        17
# 4   24-06-2018        Colombia          Poland            3        13
# 5   15-06-2018        Portugal           Spain            3         8
# 6   19-06-2018          Russia           Egypt            3        11
# 7   21-06-2018         Croatia       Argentina            3        15
# 8   27-06-2018          Sweden          Mexico            3        13
# 9   15-06-2018           Spain        Portugal            3        12
# 10  18-06-2018         Belgium          Panama            3        15
# 11  22-06-2018          Brazil      Costa Rica            2        23
# ...

# %%
new_feature = data_match.merge(data_cou, left_on='Team', right_on='Country')
new_feature
# Out:
#     level_0  index        Date            Team        Opponent  Goal Scored  \
# 0        45     58  24-06-2018         England          Panama            6
# 1        44     27  18-06-2018         England         Tunisia            2
# 2        46     94  28-06-2018         England         Belgium            0
# 3        95      0  14-06-2018          Russia    Saudi Arabia            5
# 4        96     32  19-06-2018          Russia           Egypt            3
# 5        97     65  25-06-2018          Russia         Uruguay            0
# 6        12     52  23-06-2018         Belgium         Tunisia            5
# 7        11     24  18-06-2018         Belgium          Panama            3
# 8        13     95  28-06-2018         Belgium         England            1
# 9       126     64  25-06-2018         Uruguay          Russia            3
# 10      125     36  20-06-2018         Uruguay    Saudi Arabia            1
# ...

# %%
continent = new_feature.groupby(['Continent']).sum()
continent
# Out:
#                level_0  index  Goal Scored  Ball Possession %  Attempts  \
# Continent
# Africa            1242    703           16                707       169
# Asia               894    675           13                711       153
# Europe            3018   2003           66               2139       537
# North America      531    482            7                405        95
# South America      744    697           20                838       201
#
#                On-Target  Off-Target  Blocked  Corners  Offsides  Free Kicks  \
# Continent
# Africa                49          77       43       52        24         202
# Asia                  45          65       43       60        14         220
# Europe               172         232      133      217        62         624
# North America         29          46       20       29        16         143
# South America         67          75       59       78        28         249
#
# ...

# %%
new_feature['Continent'].value_counts()
# Out:
# Europe           42
# Asia             15
# South America    15
# Africa           15
# North America     9
# Name: Continent, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
viz_1 = pd.DataFrame(data_match.groupby(['Team','On-Target']) ['Goal Scored'].sum())
viz_1
# Out:
#                           Goal Scored
# Team           On-Target
# Argentina      3                    0
#                4                    2
#                7                    1
# Australia      1                    1
#                2                    0
#                5                    1
# Belgium        4                    1
#                6                    3
#                12                   5
# Brazil         4                    1
#                6                    2
#                9                    2
# Colombia       2                    1
#                3                    4
# Costa Rica     0                    0
#                3                    0
#                6                    2
# Croatia        2                    4
#                5                    3
# Denmark        1                    0
#                3                    1
#                5                    1
# Egypt          1                    2
# ...

# %%
viz_1 = viz_1.reset_index()
viz_1.head()
# Out:
#         Team  On-Target  Goal Scored
# 0  Argentina          3            0
# 1  Argentina          4            2
# 2  Argentina          7            1
# 3  Australia          1            1
# 4  Australia          2            0

# %%
viz_1 = viz_1.groupby('Team').sum().reset_index().sort_values(by=['Goal Scored'], ascending = False)
viz_1.head()
# Out:
#        Team  On-Target  Goal Scored
# 2   Belgium         22            9
# 9   England          8            8
# 23   Russia         11            8
# 6   Croatia          7            7
# 27    Spain         12            6

# %%
viz_1 = viz_1.set_index('Team')
viz_1.head()
# Out:
#          On-Target  Goal Scored
# Team
# Belgium         22            9
# England          8            8
# Russia          11            8
# Croatia          7            7
# Spain           12            6

# %%
plt.figure(figsize = (20,20))
viz_1.loc[:,['On-Target','Goal Scored']].plot.bar()
plt.title('Relations between Goals and Shot On-Target on Every Team in FIFA World Cup')
plt.xlabel('Team')
plt.ylabel('Goal')
plt.show()

# %%
# Relasi antara tendangan on-target dan tendangan masuk tidak saling bergantungan
# Dapat dilihat bagaimana pada negara German meskipun tendangan on-target tinggi
# Namun tendangan masuk hanya kurang dari 5

# %%
plt.figure(figsize = (20,20))
sns.countplot(y=new_feature['Continent'], data=new_feature, order=new_feature['Continent'].value_counts().index)
plt.title('Total Countries in Every Continent FIFA World Cup')
plt.xlabel('Total Countries')
plt.ylabel('Continent')
plt.show()

# %%
# Benua Eropa memiliki perwakilan negara paling banyak daripada benua lainnya. 
# Dengan didominasi benua Eropa maka peluang pemenang dalam pertandingan piala dunia
# Dimenangkan oleh benua Eropa

# %%
viz_3 = pd.DataFrame(data_match.groupby(['Team']) ['Fouls Committed'].sum())
viz_3
# Out:
#                 Fouls Committed
# Team
# Argentina                    40
# Australia                    37
# Belgium                      43
# Brazil                       30
# Colombia                     40
# Costa Rica                   43
# Croatia                      55
# Denmark                      35
# Egypt                        38
# England                      33
# France                       37
# Germany                      29
# Iceland                      35
# Iran                         44
# Japan                        28
# Korea Republic               63
# Mexico                       36
# Morocco                      62
# Nigeria                      45
# Panama                       49
# Peru                         37
# Poland                       31
# Portugal                     42
# Russia                       51
# Saudi Arabia                 30
# Senegal                      44
# Serbia                       45
# Spain                        29
# ...

# %%
plt.figure(figsize = (30,30))
viz_3.loc[:,['Fouls Committed']].plot.bar()
plt.title('Counts of Fouls on Every Team in FIFA World Cup')
plt.xlabel('Team')
plt.ylabel('Fouls')
plt.show()

# %%
# Kesimpulan bahwa RRC dan Morocco 
# merupakan dua negara yang memiliki tingkat pelanggaran paling banyak 
# dalam setiap pertandingan
